# %%
# Script to convert all Agilent .D files in 01-raw_data folder to .mzML files for use in metaboigniter
# Requires Docker and Wine to run in Linux
# Converted files should appear in the 02-file_conversion folder

# %%
# Module for subprocess command
import subprocess

# %%
# Runs shell script (convert.sh) in 02-file_conversion folder that initiates the docker command to run msconvert on all .D files found in 01-raw_data
# This process can take a long time if converting a large number of files
subprocess.run(['sh','convert.sh'])
# Out:
# format: mzML
#     m/z: Compression-None, 64-bit
#     intensity: Compression-None, 32-bit
#     rt: Compression-None, 64-bit
# ByteOrder_LittleEndian
#  indexed="true"
# outputPath: /output/
# extension: .mzML
# contactFilename:
# runIndexSet:
#
# spectrum list filters:
#
# chromatogram list filters:
#
# filenames:
#   /data\c1r1-r001.d
#   /data\c1r1-r002.d
#   /data\c1r1-r003.d
#   /data\c1r3-r001.d
#   /data\c1r3-r002.d
#   /data\c1r3-r003.d
#   /data\c3r1-r001.d
#   /data\c3r1-r002.d
#   /data\c3r1-r003.d
#   /data\c3r3-r001.d
#   /data\c3r3-r002.d
#   /data\c3r3-r003.d
#   /data\c4r1-r001.d
#   /data\c4r1-r002.d
#   /data\c4r1-r003.d
#   /data\c4r3-r001.d
#   /data\c4r3-r002.d
#   /data\c4r3-r003.d
#   /data\s1r1-r001.d
#   /data\s1r1-r002.d
#   /data\s1r1-r003.d
#   /data\s1r2-r001.d
#   /data\s1r2-r002.d
#   /data\s1r2-r003.d
#   /data\s1r3-r001.d
#   /data\s1r3-r002.d
#   /data\s1r3-r003.d
#   /data\s2r1-r001.d
#   /data\s2r1-r002.d
#   /data\s2r1-r003.d
# ...
